# %% [markdown]
# # Mathplotlib- Python visualization library

# %% [markdown]
# ## What is matplotlib ?
# Mathplotlib is apython library for creating static animated and visuvalization.
#
# ## Why do we need it ?
# It helps to understand trends patterns and outliers.
#
# ## Where we use it ?
# 1.Data analysis
#
# 2.Machine learning(for plotting the loss curves)
#
# 3.to analyse the market trends, finance and scientific research.

# %% [markdown]
# ## 2. importing mathplotlib

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [10,20,25,30,40]
 
plt.plot(x, y,color='orange')
plt.title("Line Plot Example")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
categories = ['A','B','C','D']
values = [10,15,7,12]
 
plt.bar(categories, values, color='olive')
plt.title("Bar Plot Example")
plt.xlabel("categories")
plt.ylabel("values")
plt.show()

# %%
x = [5,7,8,7,2,17,2,9,4,11]
y = [99,86,87,88,100,86,103,87,94,78]
 
plt.scatter(x, y, color='blue', marker='+')
plt.title("Scatter Plot Example")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
data = [22,87,5,43,56,73,55,54,11,20,51,5,79,31,27]
 
plt.hist(data, bins=5, color='brown', edgecolor='black')
plt.title("Histogram Example")
plt.xlabel("Bins")
plt.ylabel("Frequency")
plt.show()

# %%
x = [1,2,3,4,5]
y = [2,3,5,7,11]

plt.plot(x, y, color='purple', linestyle='--', marker='o', label='Line 1')
plt.title("Customized Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend()
plt.show()

# %%
x = [1,2,3,4,5]
y1 = [2,3,5,7,11]
y2 = [1,4,6,8,10]
 
plt.subplot(1,2,1)  # 1 row, 2 columns, plot 1
plt.plot(x, y1, color='blue')
plt.title("Plot 1")
 
plt.subplot(1,2,2)  # 1 row, 2 columns, plot 2
plt.plot(x, y2, color='red')
plt.title("Plot 2")
 
plt.tight_layout()
plt.show()

# %%
plt.plot(x, y1)
plt.title("Save Plot Example")
plt.savefig("my_plot.png")  # Saves in current directory
plt.show()

# %%
labels = ['Python', 'Java', 'C++', 'Ruby']
sizes = [215, 130, 245, 210]
colors = ['gold', 'lightcoral', 'lightskyblue', 'lightgreen']
 
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title("Pie Chart Example")
plt.show()

# %%
data = [25, 30, 35, 35, 40, 45, 50, 55, 60]
plt.boxplot(data)
plt.title("Box Plot Example (Statistical Distribution)")
plt.ylabel("Values")
plt.show()

# %%
import numpy as np
data = np.random.normal(0, 1, 100)
plt.violinplot(data)
plt.title("Violin Plot Example")
plt.show()

# %%
x = np.linspace(0, 2*np.pi, 10)
y = np.cos(x)
plt.stem(x, y)
plt.title("Stem Plot Example")
plt.show()

# %%
x = [1,2,3,4,5]
y = [2,3,5,6,8]
plt.step(x, y, where='mid', color='magenta')
plt.title("Step Plot Example")
plt.show()

# %%
x = [1,2,3,4,5]
y = [2,4,6,8,10]
plt.fill_between(x, y, color='lightblue', alpha=0.6)
plt.title("Area Plot Example")
plt.show()

# %%
x = np.linspace(-3, 3, 30)
y = np.linspace(-3, 3, 30)
X, Y = np.meshgrid(x, y)
Z = np.sqrt(X**2 + Y**2)
 
plt.contour(X, Y, Z, cmap='plasma')
plt.title("Contour Plot Example")
plt.colorbar()
plt.show()

# %%
plt.contourf(X, Y, Z, cmap='viridis')
plt.title("Filled Contour Plot")
plt.colorbar()
plt.show()

# %%
theta = np.linspace(0, 2*np.pi, 100)
r = np.abs(np.sin(2*theta))
plt.polar(theta, r)
plt.title("Polar Plot Example")
plt.show()

# %%
x = np.arange(1,6)
y = np.random.randint(5,15,5)
errors = np.random.rand(5)
 
plt.errorbar(x, y, yerr=errors, fmt='o', ecolor='red', capsize=5)
plt.title("Error Bar Plot Example")
plt.show()

# %%
categories = ['A','B','C','D']
values = [10,15,7,12]
 
plt.barh(categories, values, color='orange')
plt.title("Horizontal Bar Plot")
plt.show()

# %%
days = [1,2,3,4,5]
eating = [2,3,4,3,4]
sleeping = [8,7,8,6,7]
working = [8,9,7,8,8]
 
plt.stackplot(days, eating, sleeping, working, labels=['Eating','Sleeping','Working'])
plt.legend()
plt.title("Stack Plot Example")
plt.show()

# %%
x = np.random.randn(1000)
y = np.random.randn(1000)
plt.hexbin(x, y, gridsize=25, cmap='Blues')
plt.colorbar()
plt.title("Hexbin Plot Example")
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
 
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
 
X = np.linspace(-5, 5, 30)
Y = np.linspace(-5, 5, 30)
X, Y = np.meshgrid(X, Y)
Z = np.sin(np.sqrt(X**2 + Y**2))
 
ax.plot_surface(X, Y, Z, cmap='coolwarm')
ax.set_title("3D Surface Plot")
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt
 
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
 
t = np.linspace(0, 10, 100)
x = np.sin(t)
y = np.cos(t)
z = t
 
ax.plot3D(x, y, z, 'purple')
ax.set_title("3D Line Plot")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
 
x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)
 
ax.scatter(x, y, z, color='red', marker='o')
ax.set_title("3D Scatter Plot")
plt.show()

# %%
x = np.linspace(-5, 5, 30)
y = np.linspace(-5, 5, 30)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))
 
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_wireframe(X, Y, Z, color='green')
ax.set_title("3D Wireframe Plot")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
 
X = np.linspace(-5, 5, 50)
Y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(X, Y)
Z = np.sin(np.sqrt(X**2 + Y**2))
 
ax.contour3D(X, Y, Z, 50, cmap='plasma')
ax.set_title("3D Contour Plot")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
 
x = [1, 2, 3, 4, 5]
y = [2, 3, 4, 5, 6]
z = np.zeros(5)
dx = np.ones(5)
dy = np.ones(5)
dz = [5, 2, 7, 3, 6]
 
ax.bar3d(x, y, z, dx, dy, dz, color='teal')
ax.set_title("3D Bar Plot")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
 
X = np.linspace(-5, 5, 50)
Y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(X, Y)
Z = np.cos(np.sqrt(X**2 + Y**2))
 
surf = ax.plot_surface(X, Y, Z, cmap='coolwarm', edgecolor='none')
fig.colorbar(surf)
ax.set_title("3D Surface with Colormap")
plt.show()

# %%
u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, np.pi, 100)
x = 10 * np.outer(np.cos(u), np.sin(v))
y = 10 * np.outer(np.sin(u), np.sin(v))
z = 10 * np.outer(np.ones(np.size(u)), np.cos(v))
 
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, color='skyblue')
ax.set_title("3D Sphere Surface")
plt.show()

# %%
X = np.linspace(-5, 5, 30)
Y = np.linspace(-5, 5, 30)
X, Y = np.meshgrid(X, Y)
Z = np.sin(np.sqrt(X**2 + Y**2))
 
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, alpha=0.7, cmap='viridis')
ax.plot_wireframe(X, Y, Z, color='black', linewidth=0.5)
ax.set_title("3D Surface + Wireframe")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
 
x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))
 
ax.contour(X, Y, Z, zdir='z', offset=-2, cmap='coolwarm')
ax.contour(X, Y, Z, zdir='x', offset=-5, cmap='coolwarm')
ax.contour(X, Y, Z, zdir='y', offset=5, cmap='coolwarm')
 
ax.set_title("3D Contour Projection on Planes")
plt.show()

# %%
## 1.Create a line plot of student marks across 5 exams.
import matplotlib.pyplot as plt
exams = ["dbms","python"," java"," coa"," msf"]
marks = [78, 85, 40, 88, 92]
plt.plot( marks,exams, marker='*', color='red', linestyle='-')
plt.title("Student Marks Across 5 Exams")
plt.ylabel("Exam Number")
plt.xlabel("Marks")
plt.show()

# %%
## 2.Plot a bar chart of sales of 4 products.
products = ['phone', 'laptop', 'tablet', 'smartwatch']
sales = [150, 200, 120, 80]

colors = ['blue', 'yellow', 'green', 'purple']
plt.bar(products, sales, color=colors)
plt.title("Sales of 4 Products")
plt.xlabel("Products")
plt.ylabel("Sales")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/axes/_axes.py:2365, in Axes._parse_bar_color_args(self, kwargs)
#    2364 try:
# -> 2365     facecolor = mcolors.to_rgba_array(facecolor)
#    2366 except ValueError as err:
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/colors.py:512, in to_rgba_array(c, alpha)
#     511     else:
# --> 512         rgba = np.array([to_rgba(cc) for cc in c])
#     513 else:
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/colors.py:316, in to_rgba(c, alpha)
#     315 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 316     rgba = _to_rgba_no_colorcycle(c, alpha)
#     317     try:
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/colors.py:393, in _to_rgba_no_colorcycle(c, alpha)
#     392         return c, c, c, alpha if alpha is not None else 1.
# --> 393     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     394 # turn 2-D array into 1-D array
#
# ValueError: Invalid RGBA argument: 'cayn'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[97], line 6
#       4 # Use a list of colors so each bar has a different color
#       5 colors = ['yellow', 'blue', 'cayn', 'orange']
# ----> 6 plt.bar(products, sales, color=colors)
#       7 plt.title("Sales of 4 Products")
#       8 plt.xlabel("Products")
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/pyplot.py:2981, in bar(x, height, width, bottom, align, data, **kwargs)
#    2970 @_copy_docstring_and_deprecators(Axes.bar)
#    2971 def bar(
#    2972     x: float | ArrayLike,
#    (...)
#    2979     **kwargs,
#    2980 ) -> BarContainer:
# -> 2981     return gca().bar(
#    2982         x,
#    2983         height,
#    2984         width=width,
#    2985         bottom=bottom,
#    2986         align=align,
#    2987         **({"data": data} if data is not None else {}),
#    2988         **kwargs,
#    2989     )
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/axes/_axes.py:2499, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2378 r"""
#    2379 Make a bar plot.
#    2380
#    (...)
#    2496 bar. See :doc:`/gallery/lines_bars_and_markers/bar_stacked`.
#    2497 """
#    2498 kwargs = cbook.normalize_kwargs(kwargs, mpatches.Patch)
# -> 2499 facecolor, edgecolor = self._parse_bar_color_args(kwargs)
#    2501 linewidth = kwargs.pop('linewidth', None)
#    2502 hatch = kwargs.pop('hatch', None)
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/axes/_axes.py:2367, in Axes._parse_bar_color_args(self, kwargs)
#    2365     facecolor = mcolors.to_rgba_array(facecolor)
#    2366 except ValueError as err:
# -> 2367     raise ValueError(
#    2368         "'facecolor' or 'color' argument must be a valid color or"
#    2369             "sequence of colors."
#    2370     ) from err
#    2372 return facecolor, edgecolor
#
# ValueError: 'facecolor' or 'color' argument must be a valid color orsequence of colors.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/axes/_axes.py:2365, in Axes._parse_bar_color_args(self, kwargs)
#    2364 try:
# -> 2365     facecolor = mcolors.to_rgba_array(facecolor)
#    2366 except ValueError as err:
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/colors.py:512, in to_rgba_array(c, alpha)
#     511     else:
# --> 512         rgba = np.array([to_rgba(cc) for cc in c])
#     513 else:
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/colors.py:316, in to_rgba(c, alpha)
#     315 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 316     rgba = _to_rgba_no_colorcycle(c, alpha)
#     317     try:
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/colors.py:393, in _to_rgba_no_colorcycle(c, alpha)
#     392         return c, c, c, alpha if alpha is not None else 1.
# --> 393     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     394 # turn 2-D array into 1-D array
#
# ValueError: Invalid RGBA argument: 'cayn'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[97], line 6
#       4 # Use a list of colors so each bar has a different color
#       5 colors = ['yellow', 'blue', 'cayn', 'orange']
# ----> 6 plt.bar(products, sales, color=colors)
#       7 plt.title("Sales of 4 Products")
#       8 plt.xlabel("Products")
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/pyplot.py:2981, in bar(x, height, width, bottom, align, data, **kwargs)
#    2970 @_copy_docstring_and_deprecators(Axes.bar)
#    2971 def bar(
#    2972     x: float | ArrayLike,
#    (...)
#    2979     **kwargs,
#    2980 ) -> BarContainer:
# -> 2981     return gca().bar(
#    2982         x,
#    2983         height,
#    2984         width=width,
#    2985         bottom=bottom,
#    2986         align=align,
#    2987         **({"data": data} if data is not None else {}),
#    2988         **kwargs,
#    2989     )
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/axes/_axes.py:2499, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2378 r"""
#    2379 Make a bar plot.
#    2380
#    (...)
#    2496 bar. See :doc:`/gallery/lines_bars_and_markers/bar_stacked`.
#    2497 """
#    2498 kwargs = cbook.normalize_kwargs(kwargs, mpatches.Patch)
# -> 2499 facecolor, edgecolor = self._parse_bar_color_args(kwargs)
#    2501 linewidth = kwargs.pop('linewidth', None)
#    2502 hatch = kwargs.pop('hatch', None)
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/axes/_axes.py:2367, in Axes._parse_bar_color_args(self, kwargs)
#    2365     facecolor = mcolors.to_rgba_array(facecolor)
#    2366 except ValueError as err:
# -> 2367     raise ValueError(
#    2368         "'facecolor' or 'color' argument must be a valid color or"
#    2369             "sequence of colors."
#    2370     ) from err
#    2372 return facecolor, edgecolor
#
# ValueError: 'facecolor' or 'color' argument must be a valid color orsequence of colors.

# %%
## 3.Make a scatter plot of Age vs Salary.
age = [22, 25, 30, 35, 40, 45, 50, 55, 60, 65]
salary = [30000, 35000, 40000, 45000, 50000, 60000, 65000, 70000, 80000, 90000]
plt.scatter(age, salary,linestyle='-.', color='green', marker='o')
plt.title("Age vs Salary")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.show()

# %%
## 4.Draw a histogram of marks scored by students in a class.
marks = [55, 67, 45, 70, 89, 90, 78, 66, 54, 80, 92, 88, 76, 95, 60]
plt.hist(marks,bins=10, color='cyan', edgecolor='black')
plt.title("Histogram of Student Marks")
plt.xlabel("Marks")
plt.ylabel("Number of Students")
plt.show()

# %%
## 5.Customize a plot with different colors, markers, and line styles.
x = [1,2,3,4,5]
y1 = [2,3,5,7,11]
y2 = [1,4,6,8,10]
plt.plot(x, y1, marker='o', color='blue', linestyle='--', label='Line 1')
plt.plot(x, y2, marker='s', color='red', linestyle='-.', label='Line 2')
plt.title("Customized Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend()
plt.show()

# %%
## 6.Create two subplots: Line plot and bar plot side by side.
x=[1,2,3,4,5]
y1=[3,6,4,7,6]
y2=[3,7,3,9,10]

plt.subplot(1,2,1) 
plt.plot(x, y1, color='green')
plt.title("Plot 1")
 
plt.subplot(1,2,2)  
plt.bar(x, y2, color='purple')
plt.title("Plot 2")
 
plt.tight_layout()
plt.show()
